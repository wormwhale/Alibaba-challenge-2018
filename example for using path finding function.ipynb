# %%
# import package
import numpy as np
import functools
import pandas as pd
import os
import copy
import operator

# this is a function I gave
import path_finding as pf

# %%
# when you load data, please make sure the format of them must be equal as i give here
# becasue of the requirements for our path finding function


# loading one-day data
df = pd.read_csv('./In_situMeasurementforTraining_201712_1.csv')

# change time scale 
df['hour'] = df['hour']*60-180

# load the city information
df_city = pd.read_csv('./CityData.csv')

# %%
# using this function
# pf.create_path(wind_table, city_table, city_code, date_code)

df_result = pf.create_path(df, df_city, 10, 1)

# %%
# this is a result, only for one day
df_result
# Out:
#      Date ID  Destination City ID   time  x-axis  y-axis
# 0          1                   10  00:00     142     328
# 1          1                   10  00:02     142     327
# 2          1                   10  00:04     142     326
# 3          1                   10  00:06     142     325
# 4          1                   10  00:08     142     324
# 5          1                   10  00:10     142     323
# 6          1                   10  00:12     142     322
# 7          1                   10  00:14     142     321
# 8          1                   10  00:16     142     320
# 9          1                   10  00:18     142     319
# 10         1                   10  00:20     142     318
# 11         1                   10  00:22     142     317
# 12         1                   10  00:24     142     316
# 13         1                   10  00:26     142     315
# 14         1                   10  00:28     142     314
# ...
